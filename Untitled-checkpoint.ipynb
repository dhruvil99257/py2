# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

x=pd.read_csv("auto-mpg.csv")
y=pd.DataFrame(x)
y
# Out:
#                               name  year  selling_price  ...   max_power                     torque seats
# 0           Maruti Swift Dzire VDI  2014         450000  ...      74 bhp             190Nm@ 2000rpm   5.0
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000  ...  103.52 bhp        250Nm@ 1500-2500rpm   5.0
# 2         Honda City 2017-2020 EXi  2006         158000  ...      78 bhp      12.7@ 2,700(kgm@ rpm)   5.0
# 3        Hyundai i20 Sportz Diesel  2010         225000  ...      90 bhp   22.4 kgm at 1750-2750rpm   5.0
# 4           Maruti Swift VXI BSIII  2007         130000  ...    88.2 bhp      11.5@ 4,500(kgm@ rpm)   5.0
# ...                            ...   ...            ...  ...         ...                        ...   ...
# 8123             Hyundai i20 Magna  2013         320000  ...   82.85 bhp           113.7Nm@ 4000rpm   5.0
# 8124         Hyundai Verna CRDi SX  2007         135000  ...     110 bhp  24@ 1,900-2,750(kgm@ rpm)   5.0
# ...

# %%
sns.boxplot(x["km_driven"],notch=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='km_driven'>
